# %%
#Siempre lo primero que debo hacer es importar pandas y nuimpy
import pandas as pd
import numpy as np

# %%
# Ahora subimos el archivo desde google drive, ya no tenemos que loguearnos de nuevo.
df_estudiantes=pd.read_csv('/content/drive/Shareddrives/GALIAS_COMERCIAL/PYTHON/StudentsPerformance (1) (1).csv')
df_estudiantes
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#Sigamos con la creacion de columnas usando el metodo assign o el metodo insert
#Si quiero agregar varias columnas uso el metodo assign y tambien si quiero sobreescribir una columna

# %%
#Creamos notas de fisica y filosofia aleatorias y las guardamos en variables
filosofia_score=np.random.randint(1,100,size=1000)

# %%
fisica_score=np.random.randint(1,100,size=1000)

# %%
#AHORA LE PONDRE UN INDICE A CADA FILA PARA UE SEPA DONDE VA EL DATAFRAME
filosofia_nota=pd.Series(filosofia_score, index=np.arange(0,1000))
fisica_nota=pd.Series(fisica_score, index=np.arange(0,1000))

# %%
#Ahora lo que voy a hacer es poner las nuevas columnas a mi data frame, usando assign
df_estudiantes.assign(filosofia_score=filosofia_nota, fisica_score=fisica_nota)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df_estudiantes=df_estudiantes.assign(filosofia_score=filosofia_nota, fisica_score=fisica_nota)
df_estudiantes
#Ahora vamos a usar el metodo insert, porque me permite especificar donde voy a colocar la columna
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#Ahora vamos a usar el metodo insert, porque me permite especificar donde voy a colocar la columna
#donde voy a colocar esa columna
#al usar el metodo insert debemos tener cuidado por que no devuelve notas sino que el cambio queda hecho de una vez

df_estudiantes
# Out:
#      gender  ED_SCORE race/ethnicity parental level of education  \
# 0    female        98        group B           bachelor's degree
# 1    female         8        group C                some college
# 2    female        75        group B             master's degree
# 3      male        90        group A          associate's degree
# 4      male        28        group C                some college
# ..      ...       ...            ...                         ...
# 995  female        78        group E             master's degree
# 996    male        11        group C                 high school
# 997  female        68        group C                 high school
# 998  female        60        group D                some college
# 999  female        67        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none          72             72
# ...
