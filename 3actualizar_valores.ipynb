# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#vamos a modificar valores luego de extraerlos
#lo primiero es las importanciones de panda y numopy

import pandas as pd
import numpy as np

# %%
#Traigo el archivo que voy a trabajar
df_jugadores=pd.read_csv("/content/drive/Shareddrives/GALIAS_COMERCIAL/PYTHON/players_20 (1).csv")

df_jugadores
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
#haora fijo el index usando shor name

df_jugadores=df_jugadores.set_index('short_name')

# %%
#vamos a traer solo las columnas que necesito, y voy actualizar el dataframe
df_jugadores=df_jugadores[["player_url",  "long_name",  "age",  "dob",  "height_cm",  "weight_kg",  "nationality",  "club"]]
df_jugadores.head(3)
# Out:
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
#
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain

# %%
#vamos a actualizar la estatura de messi, pero primero lo vamos a llamar
df_jugadores.loc['L. Messi', 'weight_kg']
# Out:
# 72

# %%
#Asi se modifica un dato con loc
df_jugadores.loc['L. Messi', 'weight_kg']=89

# %%
#aca muestra los datos
df_jugadores.loc['L. Messi', :]
# Out:
# player_url     https://sofifa.com/player/158023/lionel-messi/...
# long_name                         Lionel Andrés Messi Cuccittini
# age                                                           32
# dob                                                   1987-06-24
# height_cm                                                    170
# weight_kg                                                     89
# nationality                                            Argentina
# club                                                FC Barcelona
# Name: L. Messi, dtype: object

# %%
df_jugadores.loc['Cristiano Ronaldo', 'height_cm']
# Out:
# 187

# %%
#Asi se modifica un dato con loc
df_jugadores.loc['Cristiano Ronaldo', 'height_cm']=190

# %%
#aca muestra los datos
df_jugadores.loc['Cristiano Ronaldo', :]
# Out:
# player_url     https://sofifa.com/player/20801/c-ronaldo-dos-...
# long_name                    Cristiano Ronaldo dos Santos Aveiro
# age                                                           34
# dob                                                   1985-02-05
# height_cm                                                    190
# weight_kg                                                     83
# nationality                                             Portugal
# club                                                    Juventus
# Name: Cristiano Ronaldo, dtype: object

# %%
#vamos aver como actualizar elvalor de toda una columna
df_jugadores.loc[:, 'height_cm']
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    190
# Neymar Jr            175
# J. Oblak             188
# E. Hazard            175
#                     ...
# Shao Shuai           186
# Xiao Mingjie         177
# Zhang Wei            186
# Wang Haijian         185
# Pan Ximing           182
# Name: height_cm, Length: 18278, dtype: int64

# %%
#ahora la modifico
df_jugadores.loc[:, 'height_cm']=190

# %%
df_jugadores
# Out:
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# Xiao Mingjie       https://sofifa.com/player/250995/mingjie-xiao/...
# Zhang Wei          https://sofifa.com/player/252332/wei-zhang/20/...
# Wang Haijian       https://sofifa.com/player/251110/haijian-wang/...
# Pan Ximing         https://sofifa.com/player/233449/ximing-pan/20...
#
#                                              long_name  age         dob  \
# short_name
# ...

# %%
#como modificamos el ultimo registro, sin tener en cuenta quien es
df_jugadores.iloc[-1, :]
# Out:
# player_url     https://sofifa.com/player/233449/ximing-pan/20...
# long_name                                                    潘喜明
# age                                                           26
# dob                                                   1993-01-11
# height_cm                                                    190
# weight_kg                                                     78
# nationality                                             China PR
# club                                      Hebei China Fortune FC
# Name: Pan Ximing, dtype: object

# %%
#vamos a cambiar todos los datos de un jugador, dejando los datos en nulo
df_jugadores.iloc[-1, :]=np.nan

# %%
df_jugadores.iloc[-1, :]
# Out:
# player_url     NaN
# long_name      NaN
# age            NaN
# dob            NaN
# height_cm      NaN
# weight_kg      NaN
# nationality    NaN
# club           NaN
# Name: Pan Ximing, dtype: object

# %%
#ahira veamos como se pueden actualizar multiples valores de la estatura
df_jugadores.iloc[[0,1],4]=100

# %%
df_jugadores.head(4)
# Out:
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
#
#                                              long_name   age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior  27.0  1992-02-05
# J. Oblak                                     Jan Oblak  26.0  1993-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi               100.0       89.0   Argentina         FC Barcelona
# ...

# %%
#vamos a actualuzar valores cuando se cumple con una condicion
#primero definamos que querremos mostrar en una variable
columnas=['age', 'height_cm', 'weight_kg', 'nationality', 'club']
df_jugadores.loc[df_jugadores['height_cm']>180, columnas]=0
df_jugadores
# Out:
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# Xiao Mingjie       https://sofifa.com/player/250995/mingjie-xiao/...
# Zhang Wei          https://sofifa.com/player/252332/wei-zhang/20/...
# Wang Haijian       https://sofifa.com/player/251110/haijian-wang/...
# Pan Ximing                                                       NaN
#
#                                              long_name   age         dob  \
# short_name
# ...
