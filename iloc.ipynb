# %%
#A difrencias de .loc(), iloc se usa con los indices de cada elemento, esto evita que debamos coneocer todas
import pandas as pd
import numpy as np

# %%
#Traigo el archivo que voy a trabajar
df_jugadores=pd.read_csv("/content/drive/Shareddrives/GALIAS_COMERCIAL/PYTHON/players_20 (1).csv")

df_jugadores
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
#ponemos el short mane como index
df_jugadores=df_jugadores.set_index('short_name')
df_jugadores.head(5)
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
#
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# ...

# %%
#vamos a traer solo las columnas que necesito, y voy actualizar el dataframe
df_jugadores=df_jugadores[["player_url",  "long_name",  "age",  "dob",  "height_cm",  "weight_kg",  "nationality",  "club"]]
df_jugadores.head()
# Out:
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
#
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# ...

# %%
#ahora usaremos el iloc
df_jugadores.iloc[1]
# Out:
# player_url     https://sofifa.com/player/20801/c-ronaldo-dos-...
# long_name                    Cristiano Ronaldo dos Santos Aveiro
# age                                                           34
# dob                                                   1985-02-05
# height_cm                                                    187
# weight_kg                                                     83
# nationality                                             Portugal
# club                                                    Juventus
# Name: Cristiano Ronaldo, dtype: object

# %%
#ahora usaremos el iloc
df_jugadores.iloc[1,4]
# Out:
# 187

# %%
#Para obtener el club de neymar
df_jugadores.iloc[2,7]
# Out:
# 'Paris Saint-Germain'

# %%
#Para obtener el nomvre compelto de trodos los jugadores:
df_jugadores.iloc[ :, 1 ]
# Out:
# short_name
# L. Messi                  Lionel Andrés Messi Cuccittini
# Cristiano Ronaldo    Cristiano Ronaldo dos Santos Aveiro
# Neymar Jr                  Neymar da Silva Santos Junior
# J. Oblak                                       Jan Oblak
# E. Hazard                                    Eden Hazard
#                                     ...
# Shao Shuai                                            邵帅
# Xiao Mingjie                                Mingjie Xiao
# Zhang Wei                                             张威
# Wang Haijian                                         汪海健
# Pan Ximing                                           潘喜明
# Name: long_name, Length: 18278, dtype: object

# %%
df_jugadores.iloc[ :, 6]
# Out:
# short_name
# L. Messi             Argentina
# Cristiano Ronaldo     Portugal
# Neymar Jr               Brazil
# J. Oblak              Slovenia
# E. Hazard              Belgium
#                        ...
# Shao Shuai            China PR
# Xiao Mingjie          China PR
# Zhang Wei             China PR
# Wang Haijian          China PR
# Pan Ximing            China PR
# Name: nationality, Length: 18278, dtype: object

# %%
#Ahora vamos a traer solo los datos de un jugador
df_jugadores.iloc[3, :]
# Out:
# player_url     https://sofifa.com/player/200389/jan-oblak/20/...
# long_name                                              Jan Oblak
# age                                                           26
# dob                                                   1993-01-07
# height_cm                                                    188
# weight_kg                                                     87
# nationality                                             Slovenia
# club                                             Atlético Madrid
# Name: J. Oblak, dtype: object

# %%
#Ahora vamos a traer solo los datos de un jugador
df_jugadores.iloc[-1, :]
# Out:
# player_url     https://sofifa.com/player/233449/ximing-pan/20...
# long_name                                                    潘喜明
# age                                                           26
# dob                                                   1993-01-11
# height_cm                                                    182
# weight_kg                                                     78
# nationality                                             China PR
# club                                      Hebei China Fortune FC
# Name: Pan Ximing, dtype: object

# %%
#obener los datos de varias personas:
df_jugadores.iloc[[2, 1],:]
# Out:
#                                                           player_url  \
# short_name
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#                                              long_name  age         dob  \
# short_name
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#                    height_cm  weight_kg nationality                 club
# short_name
# Neymar Jr                175         68      Brazil  Paris Saint-Germain
# Cristiano Ronaldo        187         83    Portugal             Juventus

# %%
#obener los datos de varias personas:
df_jugadores.iloc[[2],[4,5]]
# Out:
#             height_cm  weight_kg
# short_name
# Neymar Jr         175         68

# %%
#obener varios datos de varias personas:
df_jugadores.iloc[[0,1],[4,5]]
# Out:
#                    height_cm  weight_kg
# short_name
# L. Messi                 170         72
# Cristiano Ronaldo        187         83

# %%
#obener varios datos de varias personas:
jugadores=[0,1]
df_jugadores.iloc[jugadores, 2:]
# Out:
#                    age         dob  height_cm  weight_kg nationality  \
# short_name
# L. Messi            32  1987-06-24        170         72   Argentina
# Cristiano Ronaldo   34  1985-02-05        187         83    Portugal
#
#                            club
# short_name
# L. Messi           FC Barcelona
# Cristiano Ronaldo      Juventus

# %%
#obener los datos de los jugadores top 10
top_10=[0,10]
df_jugadores.iloc[top_10, 2:]
# Out:
#             age         dob  height_cm  weight_kg nationality  \
# short_name
# L. Messi     32  1987-06-24        170         72   Argentina
# K. Mbappé    20  1998-12-20        178         73      France
#
#                            club
# short_name
# L. Messi           FC Barcelona
# K. Mbappé   Paris Saint-Germain

# %%
df_jugadores.iloc[0:10, :]
# Out:
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# K. De Bruyne       https://sofifa.com/player/192985/kevin-de-bruy...
# M. ter Stegen      https://sofifa.com/player/192448/marc-andre-te...
# V. van Dijk        https://sofifa.com/player/203376/virgil-van-di...
# L. Modrić          https://sofifa.com/player/177003/luka-modric/2...
# M. Salah           https://sofifa.com/player/209331/mohamed-salah...
#
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# ...

# %%
#vamos a combinar condiciones usando el iloc
#vamos a filrar jugadores que sean mas altos a 180 cm y que sean argentinos

# %%
df_jugadores.iloc[list((df_jugadores['height_cm']>180) & (df_jugadores['nationality']=='Argentina')), :]
# Out:
#                                                        player_url  \
# short_name
# M. Icardi       https://sofifa.com/player/201399/mauro-icardi/...
# G. Higuaín      https://sofifa.com/player/167664/gonzalo-higua...
# E. Garay        https://sofifa.com/player/170481/ezequiel-gara...
# N. Otamendi     https://sofifa.com/player/192366/nicolas-otame...
# G. Rulli        https://sofifa.com/player/215316/geronimo-rull...
# ...                                                           ...
# T. Durso        https://sofifa.com/player/240955/tomas-durso/2...
# J. Hass         https://sofifa.com/player/247295/joaquin-hass/...
# R. Ferrario     https://sofifa.com/player/245057/rafael-ferrar...
# L. Finochietto  https://sofifa.com/player/241099/leandro-finoc...
# N. Forastiero   https://sofifa.com/player/246841/nicolas-foras...
#
#                                   long_name  age         dob  height_cm  \
# short_name
# M. Icardi       Mauro Emanuel Icardi Rivero   26  1993-02-19        181
# ...
