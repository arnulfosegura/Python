# 4                       TERRA CASTILLA TORRE 7         Lanzado     Activo
# 5                       TERRA CASTILLA TORRE 6         Lanzado     Activo
# 6                       TERRA CASTILLA TORRE 1         Lanzado     Activo
# 7              RESERVA DE LLANO GRANDE TORRE 9         Lanzado  No activo
# 8              RESERVA DE LLANO GRANDE TORRE 8         Lanzado  No activo
# 9              RESERVA DE LLANO GRANDE TORRE 7         Lanzado  No activo
# 10             RESERVA DE LLANO GRANDE TORRE 6         Lanzado  No activo
# 11             RESERVA DE LLANO GRANDE TORRE 5         Lanzado  No activo
# ...

# %%
fechas.index
# Out:
# RangeIndex(start=0, stop=60, step=1)

# %%
fechas.columns
# Out:
# Index(['Proyecto', 'Estado Proyecto', 'Estado', 'Fecha Lanzamiento',
#        'Corte de Cartera', 'Fecha Interna', 'Fecha Externa',
#        'Fecha Escrituracion', 'fecha Cobro Cesantias', 'Observacion',
#        'Inventario', 'Venta', 'Disponible', 'Precio'],
#       dtype='object')

# %%
fechas.dtypes
# Out:
# Proyecto                 object
# Estado Proyecto          object
# Estado                   object
# Fecha Lanzamiento        object
# Corte de Cartera         object
# Fecha Interna            object
# Fecha Externa            object
# Fecha Escrituracion      object
# fecha Cobro Cesantias    object
# Observacion              object
# Inventario                int64
# Venta                     int64
# Disponible                int64
# Precio                    int64
# dtype: object

# %%
fechas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Proyecto               60 non-null     object
#  1   Estado Proyecto        60 non-null     object
#  2   Estado                 60 non-null     object
#  3   Fecha Lanzamiento      60 non-null     object
#  4   Corte de Cartera       60 non-null     object
#  5   Fecha Interna          60 non-null     object
#  6   Fecha Externa          60 non-null     object
#  7   Fecha Escrituracion    60 non-null     object
#  8   fecha Cobro Cesantias  24 non-null     object
#  9   Observacion            60 non-null     object
#  10  Inventario             60 non-null     int64
#  11  Venta                  60 non-null     int64
#  12  Disponible             60 non-null     int64
#  13  Precio                 60 non-null     int64
# dtypes: int64(4), object(10)
# ...

# %%
fechas.describe()
# Out:
#        Inventario       Venta  Disponible        Precio
# count   60.000000   60.000000   60.000000  6.000000e+01
# mean   121.383333   89.933333   31.450000  1.756727e+08
# std    111.637442  117.858989   58.109897  2.158468e+07
# min     20.000000    0.000000    0.000000  1.138000e+08
# 25%     20.000000    0.000000    4.500000  1.517000e+08
# 50%     48.000000    0.000000   20.000000  1.835500e+08
# 75%    219.250000  205.000000   20.000000  1.950000e+08
# max    334.000000  320.000000  219.000000  1.950000e+08

# %%
len(fechas)
# Out:
# 60

# %%
max(fechas)
# Out:
# 'fecha Cobro Cesantias'

# %%
max(fechas.index)
# Out:
# 59

# %%
type(fechas)
# Out:
# pandas.core.frame.DataFrame

# %%
fechas
# Out:
#                                       Proyecto Estado Proyecto     Estado  \
# 0   URBANIZACION MIRADOR DE LLANO GRANDE MZ 27         Lanzado  No activo
# 1   URBANIZACION MIRADOR DE LLANO GRANDE MZ 26         Lanzado  No activo
